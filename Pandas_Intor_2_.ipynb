# %% [markdown]
# <a href="https://colab.research.google.com/github/Huniiiii/Pandas-Intro/blob/main/Pandas_Intor_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df_data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_data.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df_data.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df_data.shape
# Out:
# (169, 4)

# %%
# select rows with Duration 75?
df_data["Duration"].loc[75]
df_data[(df_data["Duration"] == 75)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df_data[df_data.isna().any(axis=1)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 17         45     90       112       NaN
# 27         60    103       132       NaN
# 91         45    107       137       NaN
# 118        60    105       125       NaN
# 141        60     97       127       NaN

# %%
df_data.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df_data.columns.to_list()
# Out:
# ['Duration', 'Pulse', 'Maxpulse', 'Calories']

# %%
## select all duplicated rows
df_data[df_data.duplicated()]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 40         45     90       112     180.1
# 71         60    109       153     387.6
# 113        45    100       120     225.3
# 155        60    111       151     368.5

# %%
df_data[df_data.duplicated(keep = False)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 5          60    102       127     300.0
# 16         60    100       120     300.0
# 31         45     90       112     180.1
# 36         60    102       127     300.0
# 37         60    100       120     300.0
# 38         60    100       120     300.0
# 40         45     90       112     180.1
# 46         60    109       153     387.6
# 71         60    109       153     387.6
# 84         45    100       120     225.3
# 113        45    100       120     225.3
# 124        60    111       151     368.5
# 155        60    111       151     368.5

# %%
df_data[(df_data["Duration"] == 60) & (df_data["Pulse"] == 102) & (df_data["Maxpulse"] == 127)  & (df_data["Calories"])]
# Out:
#     Duration  Pulse  Maxpulse  Calories
# 5         60    102       127     300.0
# 36        60    102       127     300.0

# %%
# deleting dupllicated rows
df_data.drop_duplicates() # copy then delect the duplicate
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [162 rows x 4 columns]

# %%
 #deleting dupllicated rows and save it
df_data.drop_duplicates(inplace = True)
df_data
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [162 rows x 4 columns]

# %%
#change the index of names to a,b,c,d
df_data.rename(columns={'Duration': 'a', 'Pulse': 'b', 'Maxpulse' : 'c', 'Calories': 'd'})
# Out:
#       a    b    c      d
# 0    60  110  130  409.1
# 1    60  117  145  479.0
# 2    60  103  135  340.0
# 3    45  109  175  282.4
# 4    45  117  148  406.0
# ..   ..  ...  ...    ...
# 164  60  105  140  290.8
# 165  60  110  145  300.0
# 166  60  115  145  310.2
# 167  75  120  150  320.4
# 168  75  125  150  330.4
#
# [162 rows x 4 columns]

# %% [markdown]
# ### Quality Data

# %%
#shape
df_quality.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-719e63b36bf6> in <module>()
#       1 #shape
# ----> 2 df_quality.shape
#
# NameError: name 'df_quality' is not defined

# %%
# check columns
df_quality.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3e4a0030a477> in <module>()
#       1 # check columns
# ----> 2 df_quality.columns
#
# NameError: name 'df_quality' is not defined
